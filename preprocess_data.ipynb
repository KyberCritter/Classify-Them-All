# %% [markdown]
# # Preprocess Data Alternate
#
# Scott Ratchford, (c) 2025
#
# See LICENSE.txt for license information.
#
# This file performs preprocessing for the Pokemon data used for this project.
#
# This file uses a smaller Pokemon image dataset than `preprocess_data.ipynb`. This dataset contains no duplicate data, but it also contains fewer images. This is beneficial because the larger dataset contains many grayscale and "shiny" (extremely rare alternate Pokemon forms) images.
#
# ## Data
#
# 1. Pokemon Images - [Pokemon with Stats and Images by Christoffer MS, Kaggle](https://www.kaggle.com/datasets/christofferms/pokemon-with-stats-and-image)
# 2. Pokemon Statistics - ["Pokemon Pokedex" by Kumar Arnav, Kaggle](https://www.kaggle.com/datasets/arnavvvvv/pokemon-pokedex)

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Instructions
#
# 1. Download and unzip the `.zip` versions of each dataset mentioned above.
# 2. Update the

# %% [markdown]
# ### Imports

# %%
from collections import Counter
import os
import pandas as pd
import PIL
from PIL import Image
import random
import shutil
from typing import Tuple
import webcolors
from webcolors._definitions import _get_hex_to_name_map
import numpy as np

# %% [markdown]
# ### Parameters

# %%
# Seed the random number generator
random.seed(151)

# Defines train-test split
train_percent = 0.8   # If train percent is 80%, test percent is 20%

CWD = os.getcwd()

# Input paths for data (modify as required)
PKMN_IMG_ALT_DIR = os.path.join(CWD, "data", "pokemon_images", "images")        # Directory containing all Pokemon images
POKEDEX_ALT_PATH = os.path.join(CWD, "data", "pokemon_images", "pokedex.csv")   # Modified .csv file from "Pokemon with Stats and Images"
PKMN_STATS_PATH = os.path.join(CWD, "data", "pokemon_stats.csv")                # .csv file from "Pokemon Pokedex"

# Output paths for created and modified data (modify as required)
PKMN_IMG_COLORS_ALT_PATH = os.path.join(CWD, "pokemon_colors.csv")              # Pokemon color data output

# %% [markdown]
# ### Load Data

# %%
pokedex_df = pd.read_csv(POKEDEX_ALT_PATH, index_col=0)
num_pkmn = pokedex_df.shape[0]
pokedex_df["Name"] = pokedex_df["Name"].apply(lambda x: x.lower())

print(f"Loaded {num_pkmn} Pokemon.")
# Out:
# Loaded 1215 Pokemon.

# %% [markdown]
# ### Preprocessing Data

# %% [markdown]
# #### Add Pokemon Numbers to Data

# %%
# Load Pokedex numbers from stats file
pkmn_numbers = pd.read_csv(PKMN_STATS_PATH)
numbers_keep_cols = ["Number", "Name", ]
numbers_drop_cols = [col for col in pkmn_numbers.columns if col not in numbers_keep_cols]
pkmn_numbers = pkmn_numbers.drop(labels=numbers_drop_cols, axis=1)
pkmn_numbers["Name"] = pkmn_numbers["Name"].apply(lambda x: x.lower())

# Add Pokedex numbers to main dataset
pokedex_df = pd.merge(pokedex_df, pkmn_numbers, on=["Name", ], how="inner")
# missing_df = pd.merge(pokedex_df, pkmn_numbers, on=["Name", ], how="outer", indicator=True)
# missing_df = missing_df.query("_merge != \"both\"")

# %% [markdown]
# ### Drop Ignored Pokemon

# %%
ignored_pkmn = pokedex_df[pokedex_df["Ignore"] == True].shape[0]
pokedex_df = pokedex_df[pokedex_df["Ignore"] == False]
num_pkmn = pokedex_df.shape[0]

print(f"{num_pkmn} Pokemon remain after dropping {ignored_pkmn} Pokemon. The dropped Pokemon were ignored or their numbers were missing from the data set.")
# Out:
# 959 Pokemon remain after dropping 2 Pokemon. The dropped Pokemon were ignored or their numbers were missing from the data set.

# %% [markdown]
# ### Split Pokemon into Test and Training
#
# Split Pokemon into test and training data sets.

# %%
# Randomly shuffle the Pokedex
pokedex_df = pokedex_df.sample(frac=1).reset_index(drop=True)

num_train_pkmn = int(num_pkmn * train_percent)
num_test_pkmn = num_pkmn - num_train_pkmn

train_pct = f"{train_percent * 100:.0f}"
test_pct = f"{(1 - train_percent) * 100:.0f}"

# Apply Train column values (randomly distributed)
train_values = np.full(shape=num_train_pkmn, fill_value=True, dtype=bool)
test_values = np.full(shape=num_test_pkmn, fill_value=False, dtype=bool)
pokedex_df["Train"] = pd.Series(np.concat([train_values, test_values]))

pokedex_train_df = pokedex_df[pokedex_df["Train"] == True]
pokedex_test_df = pokedex_df[pokedex_df["Train"] == False]

# Ensure values were correctly applied
if (pokedex_train_df.shape[0] != num_train_pkmn) or (pokedex_test_df.shape[0] != num_test_pkmn):
    raise ValueError("Pokedex train values were not applied correctly.")

print(f"The dataset of {num_pkmn} Pokemon was split into {num_train_pkmn} training Pokemon and {num_test_pkmn} testing Pokemon, a {train_pct}:{test_pct} split.")
# Out:
# The dataset of 959 Pokemon was split into 767 training Pokemon and 192 testing Pokemon, a 80:20 split.

# %% [markdown]
# ## Analyze Pokemon Image Colors

# %% [markdown]
# ### Color Analysis Functions

# %%
COLOR_DICT = {
    # '#00ffff': 'aqua',
    '#000000': 'black',
    '#0000ff': 'blue',
    '#ff00ff': 'pink',
    '#008000': 'green',
    # '#808080': 'gray',
    # '#00ff00': 'lime',
    # '#800000': 'maroon',
    # '#000080': 'navy',
    # '#808000': 'olive',
    '#800080': 'purple',
    '#ff0000': 'red',
    # '#c0c0c0': 'silver',
    # '#008080': 'teal',
    '#ffffff': 'white',
    '#ffff00': 'yellow',
    '#d29214': 'orange',
}
COLOR_NAMES = list(COLOR_DICT.values())

# %%
def closest_color(requested_color: Tuple[int, int, int]) -> str:
    """
    Given an RGB tuple, find the closest color name based on Euclidean distance.
    
    Parameters:
        requested_color (Tuple[int, int, int]): The RGB color tuple.
        
    Returns:
        str: The name of the closest color.
    """
    min_distance = float('inf')
    closest_name = None
    for hex, name in COLOR_DICT.items():
        rgb = webcolors.hex_to_rgb(hex)
        distance = sum((comp1 - comp2) ** 2 for comp1, comp2 in zip(requested_color, rgb))
        if distance < min_distance:
            min_distance = distance
            closest_name = name
    
    return closest_name

def image_color_breakdown(image_path: str) -> pd.DataFrame:
    """
    Given the path to a PNG image, compute the percentage breakdown
    of the colors present in the image.
    Transparent pixels (alpha == 0) are ignored.
    
    Parameters:
        image_path (str): The path to the PNG image.
        
    Returns:
        pd.DataFrame: A DataFrame with columns for colors
    """
    # Open the image in RGBA mode to handle transparency.
    img = Image.open(image_path).convert('RGBA')
    # Filter out pixels where the alpha channel is 0 (fully transparent).
    pixels = [pixel for pixel in img.getdata() if pixel[3] != 0]
    
    if not pixels:
        raise ValueError("No non-transparent pixels found in the image.")
    
    total_pixels = len(pixels)
    
    # Count the occurrences of each allowed color.
    color_counts = Counter()
    for pixel in pixels:
        rgb = pixel[:3]
        color_name = color_name = closest_color(rgb)
        color_counts[color_name] += 1
    
    # Prepare the breakdown dictionary with all allowed colors.
    breakdown = {}
    for color in COLOR_NAMES:
        breakdown[color] = 0.0  # default 0%
    
    # Compute the percentage for each color that occurred.
    for color, count in color_counts.items():
        breakdown[color] = (count / total_pixels) * 100
    
    # Create the DataFrame with the columns in the required order.
    df = pd.DataFrame([breakdown], columns=COLOR_NAMES)
    
    return df

# %% [markdown]
# ## Analyze Training Pokemon Image Colors

# %%
drop_cols = ['Total', 'HP', 'Attack', 'Defense', 'SP. Atk.', 'SP. Def', 'Speed', 'Ignore', ]
create_cols = COLOR_NAMES.copy()

# %%
pkmn_color_train_df = pokedex_train_df.drop(labels=drop_cols, axis=1)
for col in create_cols:
    pkmn_color_train_df[col] = np.nan

for i, row in pkmn_color_train_df.iterrows():
    img_path = os.path.join(PKMN_IMG_ALT_DIR, row["Filename"])
    temp_df = image_color_breakdown(img_path)
    for col in temp_df.columns:
        pkmn_color_train_df.at[i, col] = temp_df.at[0, col]
    print(f"Finished analyzing the colors of the Pokemon {row["Name"].capitalize()}.")

print("Analyzed the colors of all training Pokemon images.")
# Out:
# Finished analyzing the colors of the Pokemon Flaaffy.
# Finished analyzing the colors of the Pokemon Totodile.
# Finished analyzing the colors of the Pokemon Snubbull.
# Finished analyzing the colors of the Pokemon Florges.
# Finished analyzing the colors of the Pokemon Karrablast.
# Finished analyzing the colors of the Pokemon Sawsbuck.
# Finished analyzing the colors of the Pokemon Pansear.
# Finished analyzing the colors of the Pokemon Lanturn.
# Finished analyzing the colors of the Pokemon Roaring moon.
# Finished analyzing the colors of the Pokemon Machoke.
# Finished analyzing the colors of the Pokemon Durant.
# Finished analyzing the colors of the Pokemon Roggenrola.
# Finished analyzing the colors of the Pokemon Grovyle.
# Finished analyzing the colors of the Pokemon Ferroseed.
# Finished analyzing the colors of the Pokemon Scovillain.
# Finished analyzing the colors of the Pokemon Gliscor.
# Finished analyzing the colors of the Pokemon Salandit.
# Finished analyzing the colors of the Pokemon Iron boulder.
# Finished analyzing the colors of the Pokemon Palossand.
# Finished analyzing the colors of the Pokemon Exploud.
# Finished analyzing the colors of the Pokemon Morelull.
# Finished analyzing the colors of the Pokemon Ponyta.
# Finished analyzing the colors of the Pokemon Teddiursa.
# Finished analyzing the colors of the Pokemon Delcatty.
# Finished analyzing the colors of the Pokemon Barboach.
# Finished analyzing the colors of the Pokemon Kadabra.
# Finished analyzing the colors of the Pokemon Girafarig.
# Finished analyzing the colors of the Pokemon Stunfisk.
# Finished analyzing the colors of the Pokemon Aggron.
# Finished analyzing the colors of the Pokemon Bastiodon.
# Finished analyzing the colors of the Pokemon Hitmonchan.
# Finished analyzing the colors of the Pokemon Primeape.
# Finished analyzing the colors of the Pokemon Bramblin.
# Finished analyzing the colors of the Pokemon Cofagrigus.
# Finished analyzing the colors of the Pokemon Corviknight.
# Finished analyzing the colors of the Pokemon Unown.
# Finished analyzing the colors of the Pokemon Torterra.
# Finished analyzing the colors of the Pokemon Meowth.
# Finished analyzing the colors of the Pokemon Runerigus.
# Finished analyzing the colors of the Pokemon Hawlucha.
# Finished analyzing the colors of the Pokemon Exeggutor.
# Finished analyzing the colors of the Pokemon Wigglytuff.
# Finished analyzing the colors of the Pokemon Nidorina.
# Finished analyzing the colors of the Pokemon Gothorita.
# Finished analyzing the colors of the Pokemon Togetic.
# Finished analyzing the colors of the Pokemon Litwick.
# Finished analyzing the colors of the Pokemon Cinccino.
# Finished analyzing the colors of the Pokemon Excadrill.
# Finished analyzing the colors of the Pokemon Wurmple.
# Finished analyzing the colors of the Pokemon Alcremie.
# Finished analyzing the colors of the Pokemon Prinplup.
# Finished analyzing the colors of the Pokemon Seismitoad.
# Finished analyzing the colors of the Pokemon Sizzlipede.
# Finished analyzing the colors of the Pokemon Chesnaught.
# Finished analyzing the colors of the Pokemon Fidough.
# Finished analyzing the colors of the Pokemon Slither wing.
# Finished analyzing the colors of the Pokemon Wooloo.
# Finished analyzing the colors of the Pokemon Cubchoo.
# Finished analyzing the colors of the Pokemon Xurkitree.
# Finished analyzing the colors of the Pokemon Poochyena.
# Finished analyzing the colors of the Pokemon Golurk.
# Finished analyzing the colors of the Pokemon Timburr.
# Finished analyzing the colors of the Pokemon Articuno.
# Finished analyzing the colors of the Pokemon Floragato.
# Finished analyzing the colors of the Pokemon Zweilous.
# Finished analyzing the colors of the Pokemon Wyrdeer.
# Finished analyzing the colors of the Pokemon Loudred.
# Finished analyzing the colors of the Pokemon Genesect.
# Finished analyzing the colors of the Pokemon Charmander.
# Finished analyzing the colors of the Pokemon Corphish.
# Finished analyzing the colors of the Pokemon Glameow.
# Finished analyzing the colors of the Pokemon Spheal.
# Finished analyzing the colors of the Pokemon Veluza.
# Finished analyzing the colors of the Pokemon Tapu koko.
# Finished analyzing the colors of the Pokemon Iron valiant.
# Finished analyzing the colors of the Pokemon Reuniclus.
# Finished analyzing the colors of the Pokemon Blastoise.
# Finished analyzing the colors of the Pokemon Cranidos.
# Finished analyzing the colors of the Pokemon Larvitar.
# Finished analyzing the colors of the Pokemon Snom.
# Finished analyzing the colors of the Pokemon Braviary.
# Finished analyzing the colors of the Pokemon Ledyba.
# Finished analyzing the colors of the Pokemon Araquanid.
# Finished analyzing the colors of the Pokemon Panpour.
# Finished analyzing the colors of the Pokemon Woobat.
# Finished analyzing the colors of the Pokemon Persian.
# Finished analyzing the colors of the Pokemon Sneasler.
# Finished analyzing the colors of the Pokemon Gumshoos.
# Finished analyzing the colors of the Pokemon Sneasel.
# Finished analyzing the colors of the Pokemon Magby.
# Finished analyzing the colors of the Pokemon Samurott.
# Finished analyzing the colors of the Pokemon Mandibuzz.
# Finished analyzing the colors of the Pokemon Coalossal.
# Finished analyzing the colors of the Pokemon Swampert.
# Finished analyzing the colors of the Pokemon Lapras.
# Finished analyzing the colors of the Pokemon Froakie.
# Finished analyzing the colors of the Pokemon Blacephalon.
# Finished analyzing the colors of the Pokemon Espathra.
# Finished analyzing the colors of the Pokemon Trubbish.
# Finished analyzing the colors of the Pokemon Mantine.
# Finished analyzing the colors of the Pokemon Numel.
# Finished analyzing the colors of the Pokemon Piplup.
# Finished analyzing the colors of the Pokemon Golduck.
# Finished analyzing the colors of the Pokemon Ditto.
# Finished analyzing the colors of the Pokemon Duraludon.
# Finished analyzing the colors of the Pokemon Musharna.
# Finished analyzing the colors of the Pokemon Hakamo-o.
# Finished analyzing the colors of the Pokemon Mewtwo.
# Finished analyzing the colors of the Pokemon Mamoswine.
# Finished analyzing the colors of the Pokemon Petilil.
# Finished analyzing the colors of the Pokemon Tranquill.
# Finished analyzing the colors of the Pokemon Jynx.
# Finished analyzing the colors of the Pokemon Cosmoem.
# Finished analyzing the colors of the Pokemon Cramorant.
# Finished analyzing the colors of the Pokemon Blissey.
# Finished analyzing the colors of the Pokemon Nincada.
# Finished analyzing the colors of the Pokemon Aromatisse.
# Finished analyzing the colors of the Pokemon Simisear.
# Finished analyzing the colors of the Pokemon Vileplume.
# Finished analyzing the colors of the Pokemon Torchic.
# Finished analyzing the colors of the Pokemon Illumise.
# Finished analyzing the colors of the Pokemon Lumineon.
# Finished analyzing the colors of the Pokemon Kangaskhan.
# Finished analyzing the colors of the Pokemon Rowlet.
# Finished analyzing the colors of the Pokemon Budew.
# Finished analyzing the colors of the Pokemon Skiploom.
# Finished analyzing the colors of the Pokemon Turtwig.
# Finished analyzing the colors of the Pokemon Psyduck.
# Finished analyzing the colors of the Pokemon Miltank.
# Finished analyzing the colors of the Pokemon Pikipek.
# Finished analyzing the colors of the Pokemon Delibird.
# Finished analyzing the colors of the Pokemon Passimian.
# Finished analyzing the colors of the Pokemon Pansage.
# Finished analyzing the colors of the Pokemon Bagon.
# Finished analyzing the colors of the Pokemon Bronzor.
# Finished analyzing the colors of the Pokemon Starmie.
# Finished analyzing the colors of the Pokemon Mareep.
# Finished analyzing the colors of the Pokemon Ekans.
# Finished analyzing the colors of the Pokemon Victreebel.
# Finished analyzing the colors of the Pokemon Flutter mane.
# Finished analyzing the colors of the Pokemon Melmetal.
# Finished analyzing the colors of the Pokemon Iron moth.
# Finished analyzing the colors of the Pokemon Pawmo.
# Finished analyzing the colors of the Pokemon Kyurem.
# Finished analyzing the colors of the Pokemon Shelgon.
# Finished analyzing the colors of the Pokemon Doduo.
# Finished analyzing the colors of the Pokemon Hypno.
# Finished analyzing the colors of the Pokemon Tarountula.
# Finished analyzing the colors of the Pokemon Gothitelle.
# Finished analyzing the colors of the Pokemon Toucannon.
# Finished analyzing the colors of the Pokemon Ho-oh.
# Finished analyzing the colors of the Pokemon Wobbuffet.
# Finished analyzing the colors of the Pokemon Grimer.
# Finished analyzing the colors of the Pokemon Growlithe.
# Finished analyzing the colors of the Pokemon Scatterbug.
# Finished analyzing the colors of the Pokemon Marshadow.
# Finished analyzing the colors of the Pokemon Regice.
# Finished analyzing the colors of the Pokemon Zarude.
# Finished analyzing the colors of the Pokemon Archaludon.
# Finished analyzing the colors of the Pokemon Rattata.
# Finished analyzing the colors of the Pokemon Froslass.
# Finished analyzing the colors of the Pokemon Iron thorns.
# Finished analyzing the colors of the Pokemon Tinkatuff.
# Finished analyzing the colors of the Pokemon Ledian.
# Finished analyzing the colors of the Pokemon Pachirisu.
# Finished analyzing the colors of the Pokemon Iron jugulis.
# Finished analyzing the colors of the Pokemon Mareanie.
# Finished analyzing the colors of the Pokemon Combee.
# Finished analyzing the colors of the Pokemon Rockruff.
# Finished analyzing the colors of the Pokemon Sentret.
# Finished analyzing the colors of the Pokemon Pinsir.
# Finished analyzing the colors of the Pokemon Wiglett.
# Finished analyzing the colors of the Pokemon Shellder.
# Finished analyzing the colors of the Pokemon Spoink.
# Finished analyzing the colors of the Pokemon Klang.
# Finished analyzing the colors of the Pokemon Weavile.
# Finished analyzing the colors of the Pokemon Clobbopus.
# Finished analyzing the colors of the Pokemon Liepard.
# Finished analyzing the colors of the Pokemon Glaceon.
# Finished analyzing the colors of the Pokemon Malamar.
# Finished analyzing the colors of the Pokemon Darumaka.
# Finished analyzing the colors of the Pokemon Lilligant.
# Finished analyzing the colors of the Pokemon Aron.
# Finished analyzing the colors of the Pokemon Purugly.
# Finished analyzing the colors of the Pokemon Talonflame.
# Finished analyzing the colors of the Pokemon Wugtrio.
# Finished analyzing the colors of the Pokemon Tangrowth.
# Finished analyzing the colors of the Pokemon Nidorino.
# Finished analyzing the colors of the Pokemon Chandelure.
# Finished analyzing the colors of the Pokemon Luxray.
# Finished analyzing the colors of the Pokemon Bunnelby.
# Finished analyzing the colors of the Pokemon Natu.
# Finished analyzing the colors of the Pokemon Binacle.
# Finished analyzing the colors of the Pokemon Rillaboom.
# Finished analyzing the colors of the Pokemon Iron crown.
# Finished analyzing the colors of the Pokemon Seadra.
# Finished analyzing the colors of the Pokemon Arcanine.
# Finished analyzing the colors of the Pokemon Serperior.
# Finished analyzing the colors of the Pokemon Umbreon.
# Finished analyzing the colors of the Pokemon Zoroark.
# Finished analyzing the colors of the Pokemon Weezing.
# Finished analyzing the colors of the Pokemon Unfezant.
# Finished analyzing the colors of the Pokemon Onix.
# Finished analyzing the colors of the Pokemon Mabosstiff.
# Finished analyzing the colors of the Pokemon Manaphy.
# Finished analyzing the colors of the Pokemon Scyther.
# Finished analyzing the colors of the Pokemon Staryu.
# Finished analyzing the colors of the Pokemon Ursaring.
# Finished analyzing the colors of the Pokemon Okidogi.
# Finished analyzing the colors of the Pokemon Celebi.
# Finished analyzing the colors of the Pokemon Shiinotic.
# Finished analyzing the colors of the Pokemon Xerneas.
# Finished analyzing the colors of the Pokemon Nacli.
# Finished analyzing the colors of the Pokemon Carkol.
# Finished analyzing the colors of the Pokemon Raboot.
# Finished analyzing the colors of the Pokemon Glimmora.
# Finished analyzing the colors of the Pokemon Toxel.
# Finished analyzing the colors of the Pokemon Stufful.
# Finished analyzing the colors of the Pokemon Aipom.
# Finished analyzing the colors of the Pokemon Solgaleo.
# Finished analyzing the colors of the Pokemon Taillow.
# Finished analyzing the colors of the Pokemon Shuckle.
# Finished analyzing the colors of the Pokemon Arrokuda.
# Finished analyzing the colors of the Pokemon Herdier.
# Finished analyzing the colors of the Pokemon Dragonair.
# Finished analyzing the colors of the Pokemon Zorua.
# Finished analyzing the colors of the Pokemon Marshtomp.
# Finished analyzing the colors of the Pokemon Silvally.
# Finished analyzing the colors of the Pokemon Maschiff.
# Finished analyzing the colors of the Pokemon Tentacruel.
# Finished analyzing the colors of the Pokemon Dracozolt.
# Finished analyzing the colors of the Pokemon Bruxish.
# Finished analyzing the colors of the Pokemon Mesprit.
# Finished analyzing the colors of the Pokemon Tyrantrum.
# Finished analyzing the colors of the Pokemon Moltres.
# Finished analyzing the colors of the Pokemon Pecharunt.
# Finished analyzing the colors of the Pokemon Dragalge.
# Finished analyzing the colors of the Pokemon Tauros.
# Finished analyzing the colors of the Pokemon Dipplin.
# Finished analyzing the colors of the Pokemon Beheeyem.
# Finished analyzing the colors of the Pokemon Bouffalant.
# Finished analyzing the colors of the Pokemon Kecleon.
# Finished analyzing the colors of the Pokemon Comfey.
# Finished analyzing the colors of the Pokemon Ivysaur.
# Finished analyzing the colors of the Pokemon Wingull.
# Finished analyzing the colors of the Pokemon Kingdra.
# Finished analyzing the colors of the Pokemon Munkidori.
# Finished analyzing the colors of the Pokemon Chimecho.
# Finished analyzing the colors of the Pokemon Doublade.
# Finished analyzing the colors of the Pokemon Stantler.
# Finished analyzing the colors of the Pokemon Ribombee.
# Finished analyzing the colors of the Pokemon Zubat.
# Finished analyzing the colors of the Pokemon Whismur.
# Finished analyzing the colors of the Pokemon Nihilego.
# Finished analyzing the colors of the Pokemon Vigoroth.
# Finished analyzing the colors of the Pokemon Wimpod.
# Finished analyzing the colors of the Pokemon Bounsweet.
# Finished analyzing the colors of the Pokemon Varoom.
# Finished analyzing the colors of the Pokemon Hattrem.
# Finished analyzing the colors of the Pokemon Sableye.
# Finished analyzing the colors of the Pokemon Mr. mime.
# Finished analyzing the colors of the Pokemon Hitmontop.
# Finished analyzing the colors of the Pokemon Rayquaza.
# Finished analyzing the colors of the Pokemon Ampharos.
# Finished analyzing the colors of the Pokemon Ducklett.
# Finished analyzing the colors of the Pokemon Mantyke.
# Finished analyzing the colors of the Pokemon Rhyhorn.
# Finished analyzing the colors of the Pokemon Snover.
# Finished analyzing the colors of the Pokemon Cherubi.
# Finished analyzing the colors of the Pokemon Jolteon.
# Finished analyzing the colors of the Pokemon Bronzong.
# Finished analyzing the colors of the Pokemon Tapu bulu.
# Finished analyzing the colors of the Pokemon Bidoof.
# Finished analyzing the colors of the Pokemon Bellsprout.
# Finished analyzing the colors of the Pokemon Shieldon.
# Finished analyzing the colors of the Pokemon Diancie.
# Finished analyzing the colors of the Pokemon Wattrel.
# Finished analyzing the colors of the Pokemon Bibarel.
# Finished analyzing the colors of the Pokemon Heliolisk.
# Finished analyzing the colors of the Pokemon Appletun.
# Finished analyzing the colors of the Pokemon Hatterene.
# Finished analyzing the colors of the Pokemon Sigilyph.
# Finished analyzing the colors of the Pokemon Bonsly.
# Finished analyzing the colors of the Pokemon Dartrix.
# Finished analyzing the colors of the Pokemon Swadloon.
# Finished analyzing the colors of the Pokemon Klinklang.
# Finished analyzing the colors of the Pokemon Farigiraf.
# Finished analyzing the colors of the Pokemon Simisage.
# Finished analyzing the colors of the Pokemon Pignite.
# Finished analyzing the colors of the Pokemon Slugma.
# Finished analyzing the colors of the Pokemon Walrein.
# Finished analyzing the colors of the Pokemon Brute bonnet.
# Finished analyzing the colors of the Pokemon Joltik.
# Finished analyzing the colors of the Pokemon Pelipper.
# Finished analyzing the colors of the Pokemon Meditite.
# Finished analyzing the colors of the Pokemon Spewpa.
# Finished analyzing the colors of the Pokemon Grafaiai.
# Finished analyzing the colors of the Pokemon Pichu.
# Finished analyzing the colors of the Pokemon Horsea.
# Finished analyzing the colors of the Pokemon Toxapex.
# Finished analyzing the colors of the Pokemon Dondozo.
# Finished analyzing the colors of the Pokemon Buneary.
# Finished analyzing the colors of the Pokemon Skiddo.
# Finished analyzing the colors of the Pokemon Larvesta.
# Finished analyzing the colors of the Pokemon Azurill.
# Finished analyzing the colors of the Pokemon Gouging fire.
# Finished analyzing the colors of the Pokemon Barbaracle.
# Finished analyzing the colors of the Pokemon Flareon.
# Finished analyzing the colors of the Pokemon Venusaur.
# Finished analyzing the colors of the Pokemon Nuzleaf.
# Finished analyzing the colors of the Pokemon Happiny.
# Finished analyzing the colors of the Pokemon Snivy.
# Finished analyzing the colors of the Pokemon Minccino.
# Finished analyzing the colors of the Pokemon Lurantis.
# Finished analyzing the colors of the Pokemon Lillipup.
# Finished analyzing the colors of the Pokemon Snorlax.
# Finished analyzing the colors of the Pokemon Shedinja.
# Finished analyzing the colors of the Pokemon Slowpoke.
# Finished analyzing the colors of the Pokemon Krokorok.
# Finished analyzing the colors of the Pokemon Nymble.
# Finished analyzing the colors of the Pokemon Weepinbell.
# Finished analyzing the colors of the Pokemon Incineroar.
# Finished analyzing the colors of the Pokemon Granbull.
# Finished analyzing the colors of the Pokemon Stonjourner.
# Finished analyzing the colors of the Pokemon Probopass.
# Finished analyzing the colors of the Pokemon Xatu.
# Finished analyzing the colors of the Pokemon Frillish.
# Finished analyzing the colors of the Pokemon Mankey.
# Finished analyzing the colors of the Pokemon Dunsparce.
# Finished analyzing the colors of the Pokemon Scizor.
# Finished analyzing the colors of the Pokemon Swinub.
# Finished analyzing the colors of the Pokemon Slowking.
# Finished analyzing the colors of the Pokemon Throh.
# Finished analyzing the colors of the Pokemon Abomasnow.
# Finished analyzing the colors of the Pokemon Dragapult.
# Finished analyzing the colors of the Pokemon Venomoth.
# Finished analyzing the colors of the Pokemon Arboliva.
# Finished analyzing the colors of the Pokemon Litten.
# Finished analyzing the colors of the Pokemon Escavalier.
# Finished analyzing the colors of the Pokemon Jangmo-o.
# Finished analyzing the colors of the Pokemon Flapple.
# Finished analyzing the colors of the Pokemon Eelektrik.
# Finished analyzing the colors of the Pokemon Leavanny.
# Finished analyzing the colors of the Pokemon Clawitzer.
# Finished analyzing the colors of the Pokemon Sandaconda.
# Finished analyzing the colors of the Pokemon Espurr.
# Finished analyzing the colors of the Pokemon Kricketot.
# Finished analyzing the colors of the Pokemon Poliwag.
# Finished analyzing the colors of the Pokemon Swellow.
# Finished analyzing the colors of the Pokemon Munna.
# Finished analyzing the colors of the Pokemon Gible.
# Finished analyzing the colors of the Pokemon Dewgong.
# Finished analyzing the colors of the Pokemon Leafeon.
# Finished analyzing the colors of the Pokemon Drilbur.
# Finished analyzing the colors of the Pokemon Poliwhirl.
# Finished analyzing the colors of the Pokemon Garbodor.
# Finished analyzing the colors of the Pokemon Kingler.
# Finished analyzing the colors of the Pokemon Kirlia.
# Finished analyzing the colors of the Pokemon Dodrio.
# Finished analyzing the colors of the Pokemon Arctibax.
# Finished analyzing the colors of the Pokemon Druddigon.
# Finished analyzing the colors of the Pokemon Ariados.
# Finished analyzing the colors of the Pokemon Slurpuff.
# Finished analyzing the colors of the Pokemon Tyrunt.
# Finished analyzing the colors of the Pokemon Golisopod.
# Finished analyzing the colors of the Pokemon Magmar.
# Finished analyzing the colors of the Pokemon Wartortle.
# Finished analyzing the colors of the Pokemon Volbeat.
# Finished analyzing the colors of the Pokemon Lickilicky.
# Finished analyzing the colors of the Pokemon Tympole.
# Finished analyzing the colors of the Pokemon Scrafty.
# Finished analyzing the colors of the Pokemon Suicune.
# Finished analyzing the colors of the Pokemon Metang.
# Finished analyzing the colors of the Pokemon Bewear.
# Finished analyzing the colors of the Pokemon Foongus.
# Finished analyzing the colors of the Pokemon Simipour.
# Finished analyzing the colors of the Pokemon Cyclizar.
# Finished analyzing the colors of the Pokemon Hydreigon.
# Finished analyzing the colors of the Pokemon Garchomp.
# Finished analyzing the colors of the Pokemon Cryogonal.
# Finished analyzing the colors of the Pokemon Cloyster.
# Finished analyzing the colors of the Pokemon Elekid.
# Finished analyzing the colors of the Pokemon Deerling.
# Finished analyzing the colors of the Pokemon Finizen.
# Finished analyzing the colors of the Pokemon Grimmsnarl.
# Finished analyzing the colors of the Pokemon Skitty.
# Finished analyzing the colors of the Pokemon Igglybuff.
# Finished analyzing the colors of the Pokemon Magneton.
# Finished analyzing the colors of the Pokemon Dreepy.
# Finished analyzing the colors of the Pokemon Feraligatr.
# Finished analyzing the colors of the Pokemon Cobalion.
# Finished analyzing the colors of the Pokemon Misdreavus.
# Finished analyzing the colors of the Pokemon Porygon2.
# Finished analyzing the colors of the Pokemon Klink.
# Finished analyzing the colors of the Pokemon Gardevoir.
# Finished analyzing the colors of the Pokemon Gothita.
# Finished analyzing the colors of the Pokemon Dracovish.
# Finished analyzing the colors of the Pokemon Electivire.
# Finished analyzing the colors of the Pokemon Bulbasaur.
# Finished analyzing the colors of the Pokemon Shellos.
# Finished analyzing the colors of the Pokemon Venonat.
# Finished analyzing the colors of the Pokemon Muk.
# Finished analyzing the colors of the Pokemon Beartic.
# Finished analyzing the colors of the Pokemon Cacturne.
# Finished analyzing the colors of the Pokemon Gholdengo.
# Finished analyzing the colors of the Pokemon Diggersby.
# Finished analyzing the colors of the Pokemon Cyndaquil.
# Finished analyzing the colors of the Pokemon Watchog.
# Finished analyzing the colors of the Pokemon Luvdisc.
# Finished analyzing the colors of the Pokemon Corsola.
# Finished analyzing the colors of the Pokemon Lombre.
# Finished analyzing the colors of the Pokemon Lokix.
# Finished analyzing the colors of the Pokemon Ursaluna.
# Finished analyzing the colors of the Pokemon Wooper.
# Finished analyzing the colors of the Pokemon Dustox.
# Finished analyzing the colors of the Pokemon Linoone.
# Finished analyzing the colors of the Pokemon Croconaw.
# Finished analyzing the colors of the Pokemon Cubone.
# Finished analyzing the colors of the Pokemon Skeledirge.
# Finished analyzing the colors of the Pokemon Bellibolt.
# Finished analyzing the colors of the Pokemon Overqwil.
# Finished analyzing the colors of the Pokemon Dewott.
# Finished analyzing the colors of the Pokemon Cacnea.
# Finished analyzing the colors of the Pokemon Rhyperior.
# Finished analyzing the colors of the Pokemon Raging bolt.
# Finished analyzing the colors of the Pokemon Grumpig.
# Finished analyzing the colors of the Pokemon Buzzwole.
# Finished analyzing the colors of the Pokemon Empoleon.
# Finished analyzing the colors of the Pokemon Raichu.
# Finished analyzing the colors of the Pokemon Conkeldurr.
# Finished analyzing the colors of the Pokemon Yamask.
# Finished analyzing the colors of the Pokemon Houndour.
# Finished analyzing the colors of the Pokemon Manectric.
# Finished analyzing the colors of the Pokemon Lunatone.
# Finished analyzing the colors of the Pokemon Obstagoon.
# Finished analyzing the colors of the Pokemon Diglett.
# Finished analyzing the colors of the Pokemon Nidoqueen.
# Finished analyzing the colors of the Pokemon Tapu lele.
# Finished analyzing the colors of the Pokemon Vaporeon.
# Finished analyzing the colors of the Pokemon Piloswine.
# Finished analyzing the colors of the Pokemon Hippowdon.
# Finished analyzing the colors of the Pokemon Geodude.
# Finished analyzing the colors of the Pokemon Registeel.
# Finished analyzing the colors of the Pokemon Breloom.
# Finished analyzing the colors of the Pokemon Shroodle.
# Finished analyzing the colors of the Pokemon Zekrom.
# Finished analyzing the colors of the Pokemon Squirtle.
# Finished analyzing the colors of the Pokemon Emboar.
# Finished analyzing the colors of the Pokemon Oranguru.
# Finished analyzing the colors of the Pokemon Poltchageist.
# Finished analyzing the colors of the Pokemon Polteageist.
# Finished analyzing the colors of the Pokemon Politoed.
# Finished analyzing the colors of the Pokemon Lunala.
# Finished analyzing the colors of the Pokemon Goodra.
# Finished analyzing the colors of the Pokemon Honchkrow.
# Finished analyzing the colors of the Pokemon Seedot.
# Finished analyzing the colors of the Pokemon Chewtle.
# Finished analyzing the colors of the Pokemon Charizard.
# Finished analyzing the colors of the Pokemon Klawf.
# Finished analyzing the colors of the Pokemon Omanyte.
# Finished analyzing the colors of the Pokemon Goomy.
# Finished analyzing the colors of the Pokemon Crustle.
# Finished analyzing the colors of the Pokemon Kricketune.
# Finished analyzing the colors of the Pokemon Pancham.
# Finished analyzing the colors of the Pokemon Shinx.
# Finished analyzing the colors of the Pokemon Combusken.
# Finished analyzing the colors of the Pokemon Accelgor.
# Finished analyzing the colors of the Pokemon Typhlosion.
# Finished analyzing the colors of the Pokemon Hoothoot.
# Finished analyzing the colors of the Pokemon Entei.
# Finished analyzing the colors of the Pokemon Fennekin.
# Finished analyzing the colors of the Pokemon Claydol.
# Finished analyzing the colors of the Pokemon Vikavolt.
# Finished analyzing the colors of the Pokemon Impidimp.
# Finished analyzing the colors of the Pokemon Chinchou.
# Finished analyzing the colors of the Pokemon Jellicent.
# Finished analyzing the colors of the Pokemon Barraskewda.
# Finished analyzing the colors of the Pokemon Carnivine.
# Finished analyzing the colors of the Pokemon Gligar.
# Finished analyzing the colors of the Pokemon Tadbulb.
# Finished analyzing the colors of the Pokemon Beautifly.
# Finished analyzing the colors of the Pokemon Castform.
# Finished analyzing the colors of the Pokemon Jigglypuff.
# Finished analyzing the colors of the Pokemon Drowzee.
# Finished analyzing the colors of the Pokemon Dusclops.
# Finished analyzing the colors of the Pokemon Voltorb.
# Finished analyzing the colors of the Pokemon Monferno.
# Finished analyzing the colors of the Pokemon Riolu.
# Finished analyzing the colors of the Pokemon Rufflet.
# Finished analyzing the colors of the Pokemon Ferrothorn.
# Finished analyzing the colors of the Pokemon Vanilluxe.
# Finished analyzing the colors of the Pokemon Yungoos.
# Finished analyzing the colors of the Pokemon Sobble.
# Finished analyzing the colors of the Pokemon Elgyem.
# Finished analyzing the colors of the Pokemon Shroomish.
# Finished analyzing the colors of the Pokemon Poliwrath.
# Finished analyzing the colors of the Pokemon Mudbray.
# Finished analyzing the colors of the Pokemon Snorunt.
# Finished analyzing the colors of the Pokemon Arceus.
# Finished analyzing the colors of the Pokemon Orthworm.
# Finished analyzing the colors of the Pokemon Skuntank.
# Finished analyzing the colors of the Pokemon Naganadel.
# Finished analyzing the colors of the Pokemon Buizel.
# Finished analyzing the colors of the Pokemon Drizzile.
# Finished analyzing the colors of the Pokemon Lairon.
# Finished analyzing the colors of the Pokemon Vivillon.
# Finished analyzing the colors of the Pokemon Ludicolo.
# Finished analyzing the colors of the Pokemon Skwovet.
# Finished analyzing the colors of the Pokemon Shuppet.
# Finished analyzing the colors of the Pokemon Drakloak.
# Finished analyzing the colors of the Pokemon Hitmonlee.
# Finished analyzing the colors of the Pokemon Galvantula.
# Finished analyzing the colors of the Pokemon Fraxure.
# Finished analyzing the colors of the Pokemon Palpitoad.
# Finished analyzing the colors of the Pokemon Rampardos.
# Finished analyzing the colors of the Pokemon Kleavor.
# Finished analyzing the colors of the Pokemon Milcery.
# Finished analyzing the colors of the Pokemon Gorebyss.
# Finished analyzing the colors of the Pokemon Whirlipede.
# Finished analyzing the colors of the Pokemon Grotle.
# Finished analyzing the colors of the Pokemon Spearow.
# Finished analyzing the colors of the Pokemon Blitzle.
# Finished analyzing the colors of the Pokemon Porygon-z.
# Finished analyzing the colors of the Pokemon Latios.
# Finished analyzing the colors of the Pokemon Munchlax.
# Finished analyzing the colors of the Pokemon Kyogre.
# Finished analyzing the colors of the Pokemon Chatot.
# Finished analyzing the colors of the Pokemon Carbink.
# Finished analyzing the colors of the Pokemon Gabite.
# Finished analyzing the colors of the Pokemon Tandemaus.
# Finished analyzing the colors of the Pokemon Steelix.
# Finished analyzing the colors of the Pokemon Amaura.
# Finished analyzing the colors of the Pokemon Sprigatito.
# Finished analyzing the colors of the Pokemon Brambleghast.
# Finished analyzing the colors of the Pokemon Drapion.
# Finished analyzing the colors of the Pokemon Anorith.
# Finished analyzing the colors of the Pokemon Clefable.
# Finished analyzing the colors of the Pokemon Yanmega.
# Finished analyzing the colors of the Pokemon Gulpin.
# Finished analyzing the colors of the Pokemon Duosion.
# Finished analyzing the colors of the Pokemon Mienshao.
# Finished analyzing the colors of the Pokemon Jumpluff.
# Finished analyzing the colors of the Pokemon Croagunk.
# Finished analyzing the colors of the Pokemon Ceruledge.
# Finished analyzing the colors of the Pokemon Dottler.
# Finished analyzing the colors of the Pokemon Pawmi.
# Finished analyzing the colors of the Pokemon Raticate.
# Finished analyzing the colors of the Pokemon Seel.
# Finished analyzing the colors of the Pokemon Eternatus.
# Finished analyzing the colors of the Pokemon Quilava.
# Finished analyzing the colors of the Pokemon Dedenne.
# Finished analyzing the colors of the Pokemon Sinistea.
# Finished analyzing the colors of the Pokemon Meowscarada.
# Finished analyzing the colors of the Pokemon Graveler.
# Finished analyzing the colors of the Pokemon Chingling.
# Finished analyzing the colors of the Pokemon Hippopotas.
# Finished analyzing the colors of the Pokemon Crobat.
# Finished analyzing the colors of the Pokemon Lotad.
# Finished analyzing the colors of the Pokemon Skarmory.
# Finished analyzing the colors of the Pokemon Annihilape.
# Finished analyzing the colors of the Pokemon Mew.
# Finished analyzing the colors of the Pokemon Tentacool.
# Finished analyzing the colors of the Pokemon Sceptile.
# Finished analyzing the colors of the Pokemon Chikorita.
# Finished analyzing the colors of the Pokemon Pidgeot.
# Finished analyzing the colors of the Pokemon Sunflora.
# Finished analyzing the colors of the Pokemon Dusknoir.
# Finished analyzing the colors of the Pokemon Scraggy.
# Finished analyzing the colors of the Pokemon Fomantis.
# Finished analyzing the colors of the Pokemon Miraidon.
# Finished analyzing the colors of the Pokemon Iron bundle.
# Finished analyzing the colors of the Pokemon Archen.
# Finished analyzing the colors of the Pokemon Staraptor.
# Finished analyzing the colors of the Pokemon Forretress.
# Finished analyzing the colors of the Pokemon Caterpie.
# Finished analyzing the colors of the Pokemon Swoobat.
# Finished analyzing the colors of the Pokemon Machop.
# Finished analyzing the colors of the Pokemon Noivern.
# Finished analyzing the colors of the Pokemon Crawdaunt.
# Finished analyzing the colors of the Pokemon Eelektross.
# Finished analyzing the colors of the Pokemon Swalot.
# Finished analyzing the colors of the Pokemon Dubwool.
# Finished analyzing the colors of the Pokemon Grapploct.
# Finished analyzing the colors of the Pokemon Gurdurr.
# Finished analyzing the colors of the Pokemon Centiskorch.
# Finished analyzing the colors of the Pokemon Ninjask.
# Finished analyzing the colors of the Pokemon Hariyama.
# Finished analyzing the colors of the Pokemon Fletchling.
# Finished analyzing the colors of the Pokemon Banette.
# Finished analyzing the colors of the Pokemon Pupitar.
# Finished analyzing the colors of the Pokemon Golbat.
# Finished analyzing the colors of the Pokemon Braixen.
# Finished analyzing the colors of the Pokemon Pheromosa.
# Finished analyzing the colors of the Pokemon Huntail.
# Finished analyzing the colors of the Pokemon Toedscool.
# Finished analyzing the colors of the Pokemon Groudon.
# Finished analyzing the colors of the Pokemon Trapinch.
# Finished analyzing the colors of the Pokemon Iron treads.
# Finished analyzing the colors of the Pokemon Porygon.
# Finished analyzing the colors of the Pokemon Ambipom.
# Finished analyzing the colors of the Pokemon Pidgey.
# Finished analyzing the colors of the Pokemon Paras.
# Finished analyzing the colors of the Pokemon Tepig.
# Finished analyzing the colors of the Pokemon Torkoal.
# Finished analyzing the colors of the Pokemon Hoppip.
# Finished analyzing the colors of the Pokemon Scorbunny.
# Finished analyzing the colors of the Pokemon Dewpider.
# Finished analyzing the colors of the Pokemon Spectrier.
# Finished analyzing the colors of the Pokemon Gengar.
# Finished analyzing the colors of the Pokemon Spiritomb.
# Finished analyzing the colors of the Pokemon Scolipede.
# Finished analyzing the colors of the Pokemon Lopunny.
# Finished analyzing the colors of the Pokemon Tirtouga.
# Finished analyzing the colors of the Pokemon Slaking.
# Finished analyzing the colors of the Pokemon Swirlix.
# Finished analyzing the colors of the Pokemon Fezandipiti.
# Finished analyzing the colors of the Pokemon Seaking.
# Finished analyzing the colors of the Pokemon Regirock.
# Finished analyzing the colors of the Pokemon Dragonite.
# Finished analyzing the colors of the Pokemon Nickit.
# Finished analyzing the colors of the Pokemon Great tusk.
# Finished analyzing the colors of the Pokemon Dachsbun.
# Finished analyzing the colors of the Pokemon Roselia.
# Finished analyzing the colors of the Pokemon Alakazam.
# Finished analyzing the colors of the Pokemon Greavard.
# Finished analyzing the colors of the Pokemon Dratini.
# Finished analyzing the colors of the Pokemon Corvisquire.
# Finished analyzing the colors of the Pokemon Decidueye.
# Finished analyzing the colors of the Pokemon Mienfoo.
# Finished analyzing the colors of the Pokemon Spinda.
# Finished analyzing the colors of the Pokemon Heracross.
# Finished analyzing the colors of the Pokemon Amoonguss.
# Finished analyzing the colors of the Pokemon Koraidon.
# Finished analyzing the colors of the Pokemon Raikou.
# Finished analyzing the colors of the Pokemon Necrozma.
# Finished analyzing the colors of the Pokemon Helioptile.
# Finished analyzing the colors of the Pokemon Octillery.
# Finished analyzing the colors of the Pokemon Scream tail.
# Finished analyzing the colors of the Pokemon Whimsicott.
# Finished analyzing the colors of the Pokemon Rapidash.
# Finished analyzing the colors of the Pokemon Tinkatink.
# Finished analyzing the colors of the Pokemon Rolycoly.
# Finished analyzing the colors of the Pokemon Zangoose.
# Finished analyzing the colors of the Pokemon Gallade.
# Finished analyzing the colors of the Pokemon Tangela.
# Finished analyzing the colors of the Pokemon Altaria.
# Finished analyzing the colors of the Pokemon Kubfu.
# Finished analyzing the colors of the Pokemon Lickitung.
# Finished analyzing the colors of the Pokemon Weedle.
# Finished analyzing the colors of the Pokemon Spinarak.
# Finished analyzing the colors of the Pokemon Camerupt.
# Finished analyzing the colors of the Pokemon Baxcalibur.
# Finished analyzing the colors of the Pokemon Pidgeotto.
# Finished analyzing the colors of the Pokemon Marowak.
# Finished analyzing the colors of the Pokemon Turtonator.
# Finished analyzing the colors of the Pokemon Aerodactyl.
# Finished analyzing the colors of the Pokemon Sandslash.
# Finished analyzing the colors of the Pokemon Floette.
# Finished analyzing the colors of the Pokemon Dolliv.
# Finished analyzing the colors of the Pokemon Litleo.
# Finished analyzing the colors of the Pokemon Grookey.
# Finished analyzing the colors of the Pokemon Mudkip.
# Finished analyzing the colors of the Pokemon Slowbro.
# Finished analyzing the colors of the Pokemon Frosmoth.
# Finished analyzing the colors of the Pokemon Glalie.
# Finished analyzing the colors of the Pokemon Poipole.
# Finished analyzing the colors of the Pokemon Inteleon.
# Finished analyzing the colors of the Pokemon Cascoon.
# Finished analyzing the colors of the Pokemon Dhelmise.
# Finished analyzing the colors of the Pokemon Skorupi.
# Finished analyzing the colors of the Pokemon Remoraid.
# Finished analyzing the colors of the Pokemon Houndoom.
# Finished analyzing the colors of the Pokemon Dialga.
# Finished analyzing the colors of the Pokemon Archeops.
# Finished analyzing the colors of the Pokemon Greninja.
# Finished analyzing the colors of the Pokemon Meltan.
# Finished analyzing the colors of the Pokemon Blipbug.
# Finished analyzing the colors of the Pokemon Togepi.
# Finished analyzing the colors of the Pokemon Crabominable.
# Finished analyzing the colors of the Pokemon Chespin.
# Finished analyzing the colors of the Pokemon Regieleki.
# Finished analyzing the colors of the Pokemon Gossifleur.
# Finished analyzing the colors of the Pokemon Koffing.
# Finished analyzing the colors of the Pokemon Audino.
# Finished analyzing the colors of the Pokemon Walking wake.
# Finished analyzing the colors of the Pokemon Yamper.
# Finished analyzing the colors of the Pokemon Golem.
# Finished analyzing the colors of the Pokemon Crocalor.
# Finished analyzing the colors of the Pokemon Vibrava.
# Finished analyzing the colors of the Pokemon Gyarados.
# Finished analyzing the colors of the Pokemon Flittle.
# Finished analyzing the colors of the Pokemon Hatenna.
# Finished analyzing the colors of the Pokemon Starly.
# Finished analyzing the colors of the Pokemon Electabuzz.
# Finished analyzing the colors of the Pokemon Goldeen.
# Finished analyzing the colors of the Pokemon Spritzee.
# Finished analyzing the colors of the Pokemon Cutiefly.
# Finished analyzing the colors of the Pokemon Quaxly.
# Finished analyzing the colors of the Pokemon Butterfree.
# Finished analyzing the colors of the Pokemon Smoliv.
# Finished analyzing the colors of the Pokemon Togekiss.
# Finished analyzing the colors of the Pokemon Drifblim.
# Finished analyzing the colors of the Pokemon Cradily.
# Finished analyzing the colors of the Pokemon Slakoth.
# Finished analyzing the colors of the Pokemon Greedent.
# Finished analyzing the colors of the Pokemon Pincurchin.
# Finished analyzing the colors of the Pokemon Oddish.
# Finished analyzing the colors of the Pokemon Azelf.
# Finished analyzing the colors of the Pokemon Rellor.
# Finished analyzing the colors of the Pokemon Charmeleon.
# Finished analyzing the colors of the Pokemon Avalugg.
# Finished analyzing the colors of the Pokemon Lileep.
# Finished analyzing the colors of the Pokemon Tropius.
# Finished analyzing the colors of the Pokemon Komala.
# Finished analyzing the colors of the Pokemon Heatmor.
# Finished analyzing the colors of the Pokemon Guzzlord.
# Finished analyzing the colors of the Pokemon Pidove.
# Finished analyzing the colors of the Pokemon Stunky.
# Finished analyzing the colors of the Pokemon Calyrex.
# Finished analyzing the colors of the Pokemon Regigigas.
# Finished analyzing the colors of the Pokemon Solosis.
# Finished analyzing the colors of the Pokemon Gastrodon.
# Finished analyzing the colors of the Pokemon Skrelp.
# Finished analyzing the colors of the Pokemon Seviper.
# Finished analyzing the colors of the Pokemon Makuhita.
# Finished analyzing the colors of the Pokemon Armarouge.
# Finished analyzing the colors of the Pokemon Arctovish.
# Finished analyzing the colors of the Pokemon Bombirdier.
# Finished analyzing the colors of the Pokemon Finneon.
# Finished analyzing the colors of the Pokemon Noibat.
# Finished analyzing the colors of the Pokemon Infernape.
# Finished analyzing the colors of the Pokemon Pikachu.
# Finished analyzing the colors of the Pokemon Naclstack.
# Finished analyzing the colors of the Pokemon Abra.
# Finished analyzing the colors of the Pokemon Vulpix.
# Finished analyzing the colors of the Pokemon Magearna.
# Finished analyzing the colors of the Pokemon Pyukumuku.
# Finished analyzing the colors of the Pokemon Sliggoo.
# Finished analyzing the colors of the Pokemon Krookodile.
# Finished analyzing the colors of the Pokemon Swablu.
# Finished analyzing the colors of the Pokemon Oshawott.
# Finished analyzing the colors of the Pokemon Zigzagoon.
# Finished analyzing the colors of the Pokemon Milotic.
# Finished analyzing the colors of the Pokemon Whiscash.
# Finished analyzing the colors of the Pokemon Cleffa.
# Finished analyzing the colors of the Pokemon Houndstone.
# Finished analyzing the colors of the Pokemon Charcadet.
# Finished analyzing the colors of the Pokemon Patrat.
# Finished analyzing the colors of the Pokemon Terrakion.
# Finished analyzing the colors of the Pokemon Reshiram.
# Finished analyzing the colors of the Pokemon Hydrapple.
# Finished analyzing the colors of the Pokemon Tyrogue.
# Finished analyzing the colors of the Pokemon Machamp.
# Finished analyzing the colors of the Pokemon Swanna.
# Finished analyzing the colors of the Pokemon Tapu fini.
# Finished analyzing the colors of the Pokemon Meganium.
# Finished analyzing the colors of the Pokemon Darkrai.
# Finished analyzing the colors of the Pokemon Sawk.
# Finished analyzing the colors of the Pokemon Steenee.
# Finished analyzing the colors of the Pokemon Smeargle.
# Finished analyzing the colors of the Pokemon Silcoon.
# Finished analyzing the colors of the Pokemon Quaquaval.
# Finished analyzing the colors of the Pokemon Electrode.
# Finished analyzing the colors of the Pokemon Togedemaru.
# Finished analyzing the colors of the Pokemon Kabutops.
# Finished analyzing the colors of the Pokemon Orbeetle.
# Finished analyzing the colors of the Pokemon Wynaut.
# Analyzed the colors of all training Pokemon images.

# %%
pkmn_color_test_df = pokedex_test_df.drop(labels=drop_cols, axis=1)
for col in create_cols:
    pkmn_color_test_df[col] = np.nan

for i, row in pkmn_color_test_df.iterrows():
    img_path = os.path.join(PKMN_IMG_ALT_DIR, row["Filename"])
    temp_df = image_color_breakdown(img_path)
    for col in temp_df.columns:
        pkmn_color_test_df.at[i, col] = temp_df.at[0, col]
    print(f"Finished analyzing the colors of the Pokemon {row["Name"].capitalize()}.")

print("Analyzed the colors of all testing Pokemon images.")
# Out:
# Finished analyzing the colors of the Pokemon Feebas.
# Finished analyzing the colors of the Pokemon Tinkaton.
# Finished analyzing the colors of the Pokemon Cinderace.
# Finished analyzing the colors of the Pokemon Duskull.
# Finished analyzing the colors of the Pokemon Gigalith.
# Finished analyzing the colors of the Pokemon Servine.
# Finished analyzing the colors of the Pokemon Bayleef.
# Finished analyzing the colors of the Pokemon Sharpedo.
# Finished analyzing the colors of the Pokemon Phantump.
# Finished analyzing the colors of the Pokemon Quaxwell.
# Finished analyzing the colors of the Pokemon Aurorus.
# Finished analyzing the colors of the Pokemon Vullaby.
# Finished analyzing the colors of the Pokemon Treecko.
# Finished analyzing the colors of the Pokemon Ninetales.
# Finished analyzing the colors of the Pokemon Drampa.
# Finished analyzing the colors of the Pokemon Beldum.
# Finished analyzing the colors of the Pokemon Popplio.
# Finished analyzing the colors of the Pokemon Cherrim.
# Finished analyzing the colors of the Pokemon Sylveon.
# Finished analyzing the colors of the Pokemon Yveltal.
# Finished analyzing the colors of the Pokemon Carracosta.
# Finished analyzing the colors of the Pokemon Donphan.
# Finished analyzing the colors of the Pokemon Parasect.
# Finished analyzing the colors of the Pokemon Pineco.
# Finished analyzing the colors of the Pokemon Pangoro.
# Finished analyzing the colors of the Pokemon Axew.
# Finished analyzing the colors of the Pokemon Regidrago.
# Finished analyzing the colors of the Pokemon Grubbin.
# Finished analyzing the colors of the Pokemon Murkrow.
# Finished analyzing the colors of the Pokemon Wailord.
# Finished analyzing the colors of the Pokemon Cresselia.
# Finished analyzing the colors of the Pokemon Clauncher.
# Finished analyzing the colors of the Pokemon Marill.
# Finished analyzing the colors of the Pokemon Zebstrika.
# Finished analyzing the colors of the Pokemon Venipede.
# Finished analyzing the colors of the Pokemon Baltoy.
# Finished analyzing the colors of the Pokemon Haunter.
# Finished analyzing the colors of the Pokemon Espeon.
# Finished analyzing the colors of the Pokemon Minun.
# Finished analyzing the colors of the Pokemon Azumarill.
# Finished analyzing the colors of the Pokemon Magcargo.
# Finished analyzing the colors of the Pokemon Beedrill.
# Finished analyzing the colors of the Pokemon Golett.
# Finished analyzing the colors of the Pokemon Bellossom.
# Finished analyzing the colors of the Pokemon Virizion.
# Finished analyzing the colors of the Pokemon Solrock.
# Finished analyzing the colors of the Pokemon Glimmet.
# Finished analyzing the colors of the Pokemon Sandshrew.
# Finished analyzing the colors of the Pokemon Gloom.
# Finished analyzing the colors of the Pokemon Krabby.
# Finished analyzing the colors of the Pokemon Salazzle.
# Finished analyzing the colors of the Pokemon Clefairy.
# Finished analyzing the colors of the Pokemon Delphox.
# Finished analyzing the colors of the Pokemon Omastar.
# Finished analyzing the colors of the Pokemon Gastly.
# Finished analyzing the colors of the Pokemon Quagsire.
# Finished analyzing the colors of the Pokemon Phione.
# Finished analyzing the colors of the Pokemon Rhydon.
# Finished analyzing the colors of the Pokemon Clodsire.
# Finished analyzing the colors of the Pokemon Kakuna.
# Finished analyzing the colors of the Pokemon Roserade.
# Finished analyzing the colors of the Pokemon Sandy shocks.
# Finished analyzing the colors of the Pokemon Clamperl.
# Finished analyzing the colors of the Pokemon Heatran.
# Finished analyzing the colors of the Pokemon Flamigo.
# Finished analyzing the colors of the Pokemon Shelmet.
# Finished analyzing the colors of the Pokemon Flygon.
# Finished analyzing the colors of the Pokemon Fletchinder.
# Finished analyzing the colors of the Pokemon Lucario.
# Finished analyzing the colors of the Pokemon Fuecoco.
# Finished analyzing the colors of the Pokemon Capsakid.
# Finished analyzing the colors of the Pokemon Chimchar.
# Finished analyzing the colors of the Pokemon Boldore.
# Finished analyzing the colors of the Pokemon Emolga.
# Finished analyzing the colors of the Pokemon Plusle.
# Finished analyzing the colors of the Pokemon Drednaw.
# Finished analyzing the colors of the Pokemon Bergmite.
# Finished analyzing the colors of the Pokemon Maractus.
# Finished analyzing the colors of the Pokemon Sandile.
# Finished analyzing the colors of the Pokemon Alomomola.
# Finished analyzing the colors of the Pokemon Metapod.
# Finished analyzing the colors of the Pokemon Applin.
# Finished analyzing the colors of the Pokemon Yanma.
# Finished analyzing the colors of the Pokemon Falinks.
# Finished analyzing the colors of the Pokemon Armaldo.
# Finished analyzing the colors of the Pokemon Klefki.
# Finished analyzing the colors of the Pokemon Magnezone.
# Finished analyzing the colors of the Pokemon Volcanion.
# Finished analyzing the colors of the Pokemon Floatzel.
# Finished analyzing the colors of the Pokemon Shiftry.
# Finished analyzing the colors of the Pokemon Furret.
# Finished analyzing the colors of the Pokemon Tynamo.
# Finished analyzing the colors of the Pokemon Purrloin.
# Finished analyzing the colors of the Pokemon Blaziken.
# Finished analyzing the colors of the Pokemon Luxio.
# Finished analyzing the colors of the Pokemon Kabuto.
# Finished analyzing the colors of the Pokemon Exeggcute.
# Finished analyzing the colors of the Pokemon Mime jr..
# Finished analyzing the colors of the Pokemon Rotom.
# Finished analyzing the colors of the Pokemon Nosepass.
# Finished analyzing the colors of the Pokemon Glastrier.
# Finished analyzing the colors of the Pokemon Stoutland.
# Finished analyzing the colors of the Pokemon Nidoking.
# Finished analyzing the colors of the Pokemon Absol.
# Finished analyzing the colors of the Pokemon Lampent.
# Finished analyzing the colors of the Pokemon Sandygast.
# Finished analyzing the colors of the Pokemon Stakataka.
# Finished analyzing the colors of the Pokemon Kommo-o.
# Finished analyzing the colors of the Pokemon Ralts.
# Finished analyzing the colors of the Pokemon Kartana.
# Finished analyzing the colors of the Pokemon Dwebble.
# Finished analyzing the colors of the Pokemon Rabsca.
# Finished analyzing the colors of the Pokemon Magmortar.
# Finished analyzing the colors of the Pokemon Boltund.
# Finished analyzing the colors of the Pokemon Haxorus.
# Finished analyzing the colors of the Pokemon Mawile.
# Finished analyzing the colors of the Pokemon Vespiquen.
# Finished analyzing the colors of the Pokemon Pawmot.
# Finished analyzing the colors of the Pokemon Frogadier.
# Finished analyzing the colors of the Pokemon Metagross.
# Finished analyzing the colors of the Pokemon Inkay.
# Finished analyzing the colors of the Pokemon Sudowoodo.
# Finished analyzing the colors of the Pokemon Quilladin.
# Finished analyzing the colors of the Pokemon Victini.
# Finished analyzing the colors of the Pokemon Cursola.
# Finished analyzing the colors of the Pokemon Thievul.
# Finished analyzing the colors of the Pokemon Honedge.
# Finished analyzing the colors of the Pokemon Torracat.
# Finished analyzing the colors of the Pokemon Zeraora.
# Finished analyzing the colors of the Pokemon Lugia.
# Finished analyzing the colors of the Pokemon Sealeo.
# Finished analyzing the colors of the Pokemon Primarina.
# Finished analyzing the colors of the Pokemon Smoochum.
# Finished analyzing the colors of the Pokemon Mismagius.
# Finished analyzing the colors of the Pokemon Pawniard.
# Finished analyzing the colors of the Pokemon Copperajah.
# Finished analyzing the colors of the Pokemon Silicobra.
# Finished analyzing the colors of the Pokemon Cetoddle.
# Finished analyzing the colors of the Pokemon Dugtrio.
# Finished analyzing the colors of the Pokemon Wailmer.
# Finished analyzing the colors of the Pokemon Mimikyu.
# Finished analyzing the colors of the Pokemon Chansey.
# Finished analyzing the colors of the Pokemon Thwackey.
# Finished analyzing the colors of the Pokemon Perrserker.
# Finished analyzing the colors of the Pokemon Volcarona.
# Finished analyzing the colors of the Pokemon Magikarp.
# Finished analyzing the colors of the Pokemon Farfetch'd.
# Finished analyzing the colors of the Pokemon Fearow.
# Finished analyzing the colors of the Pokemon Cufant.
# Finished analyzing the colors of the Pokemon Vanillite.
# Finished analyzing the colors of the Pokemon Bisharp.
# Finished analyzing the colors of the Pokemon Celesteela.
# Finished analyzing the colors of the Pokemon Uxie.
# Finished analyzing the colors of the Pokemon Phanpy.
# Finished analyzing the colors of the Pokemon Electrike.
# Finished analyzing the colors of the Pokemon Qwilfish.
# Finished analyzing the colors of the Pokemon Carvanha.
# Finished analyzing the colors of the Pokemon Masquerain.
# Finished analyzing the colors of the Pokemon Cosmog.
# Finished analyzing the colors of the Pokemon Vanillish.
# Finished analyzing the colors of the Pokemon Arctozolt.
# Finished analyzing the colors of the Pokemon Relicanth.
# Finished analyzing the colors of the Pokemon Frigibax.
# Finished analyzing the colors of the Pokemon Trumbeak.
# Finished analyzing the colors of the Pokemon Sunkern.
# Finished analyzing the colors of the Pokemon Gogoat.
# Finished analyzing the colors of the Pokemon Kingambit.
# Finished analyzing the colors of the Pokemon Eevee.
# Finished analyzing the colors of the Pokemon Tyranitar.
# Finished analyzing the colors of the Pokemon Zapdos.
# Finished analyzing the colors of the Pokemon Mothim.
# Finished analyzing the colors of the Pokemon Rookidee.
# Finished analyzing the colors of the Pokemon Toxicroak.
# Finished analyzing the colors of the Pokemon Latias.
# Finished analyzing the colors of the Pokemon Pyroar.
# Finished analyzing the colors of the Pokemon Salamence.
# Finished analyzing the colors of the Pokemon Staravia.
# Finished analyzing the colors of the Pokemon Lechonk.
# Finished analyzing the colors of the Pokemon Sewaddle.
# Finished analyzing the colors of the Pokemon Surskit.
# Finished analyzing the colors of the Pokemon Noctowl.
# Finished analyzing the colors of the Pokemon Arbok.
# Finished analyzing the colors of the Pokemon Drifloon.
# Finished analyzing the colors of the Pokemon Deino.
# Finished analyzing the colors of the Pokemon Cottonee.
# Finished analyzing the colors of the Pokemon Magnemite.
# Finished analyzing the colors of the Pokemon Mightyena.
# Finished analyzing the colors of the Pokemon Brionne.
# Finished analyzing the colors of the Pokemon Furfrou.
# Finished analyzing the colors of the Pokemon Jirachi.
# Finished analyzing the colors of the Pokemon Cetitan.
# Finished analyzing the colors of the Pokemon Palkia.
# Analyzed the colors of all testing Pokemon images.

# %% [markdown]
# ### Save Color Data to File

# %%
# Create a dataframe of all test images
pkmn_color_df = pd.concat([pkmn_color_test_df, pkmn_color_train_df], ignore_index=True)
pkmn_color_df.to_csv(PKMN_IMG_COLORS_ALT_PATH, sep=",")

print("Created a file with all Pokemon image color data.")
# Out:
# Created a file with all Pokemon image color data.
